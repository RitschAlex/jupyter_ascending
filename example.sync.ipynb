# %%
print("Hello world!")
print("Hello world!")
print("Hello world!")
# Out:
# Hello world!
# Hello world!
# Hello world!

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
import requests

# %% [markdown]
# ## Test
